# %%
import pandas as pd

# %%
df = pd.read_feather("C:/Users/Jason/thesis_project/data/obs_datasets/profiles/X/1997_2014meanAH.feather")

# %%
df
# Out:
#          ProfileID       date         0         1         2          3  \
# 0                3 1997-12-15  4.396250  0.673833  0.801250   0.808667
# 1                3 1997-12-16  0.668250  0.740333  0.741583   0.799250
# 2                3 1997-12-17  0.812167  0.751750  1.382000   6.623917
# 3                3 1997-12-18  0.819167  2.835167  1.289583  10.299250
# 4                3 1997-12-19  0.748833  0.996000  1.349750   4.972250
# ...            ...        ...       ...       ...       ...        ...
# 3210593   12029092 2014-09-26  0.000000  0.000000  0.000000   0.000000
# 3210594   12029092 2014-09-27  0.000000  0.000000  0.000000   0.000000
# 3210595   12029092 2014-09-28  0.000000  0.000000  0.000000   0.000000
# 3210596   12029092 2014-09-29  0.000000  0.000000  0.000000   0.000000
# 3210597   12029092 2014-09-30  0.000000  0.000000  0.000000   0.000000
#
#                  4         5          6          7  ...         14         15  \
# ...

# %%
df = pd.read_feather("C:/Users/Jason/thesis_project/data/obs_datasets/profiles/X/1997_2014meanAH.feather")
